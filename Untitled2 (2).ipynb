# %%
#Value iteration
#Agent has evaluated value of each state and in greedy way it takes the actions rather than exploring entire maze
#It has explored all posible way
#Value function will help us find the optimal policy
#Policy is mapping a behaviour of agent with respect to the state


import numpy as np
import matplotlib.pyplot as plt

from envs import Maze
from utils import plot_values, plot_policy, test_agent

# %%
#Initialize the environment
env=Maze()

# %%
frame=env.render(mode='rgb_array')
plt.figure(figsize=(6,6))
plt.axis("off")
plt.imshow(frame)

# %%
print(f"Observation space shape: {env.observation_space.nvec}")
print(f"Action space shape: {env.action_space.n}")
# Out:
# Observation space shape: [5 5]
# Action space shape: 4

# %%
#Define the policy
#Create the policy
policy_probs=np.full((5,5,4),0.25)
policy_probs
# Out:
# array([[[0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25]],
#
#        [[0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25]],
#
#        [[0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25]],
#
#        [[0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25]],
#
#        [[0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25],
#         [0.25, 0.25, 0.25, 0.25]]])

# %%
def policy(state):
  return policy_probs[state]

# %%
#Test the policy with state (0,0)
action_probabilities=policy((0,0))
for action, prob in zip(range(4),action_probabilities):
  print(f"Probabilities of taking action {action}: {prob}")
# Out:
# Probabilities of taking action 0: 0.25
# Probabilities of taking action 1: 0.25
# Probabilities of taking action 2: 0.25
# Probabilities of taking action 3: 0.25

# %%
#Zip is like an inline function, it is kind of lookup table
#See how the random policy does in the maze
test_agent(env,policy,episodes=1)

# %%
np.object=object
plot_policy(policy_probs,frame)

# %%
#Create the v(s) table

state_values=np.zeros(shape=(5,5))
env.observation_space
# Out:
# MultiDiscrete([5 5])
